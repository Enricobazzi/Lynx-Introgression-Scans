# %%
import sys

# %%
if "process_dadi_results" in sys.modules:
    del sys.modules["process_dadi_results"]
import process_dadi_results

# %%
opti_table = 'tables/optimizations/ordered_opti_table.tsv'

# %%
real_params = process_dadi_results.print_processed_table(opti_table)
# Out:
# nth_best	model	pop_pair	log-likelihood	Nref	Tsplit	Tbot1	Tbot2	N_iber_c	N_iber_i	N_iber_a	N_eura_c	N_eura_a	ancient_mig	inter_mig_12	inter_mig_21	recent_mig_12	ecent_mig_21
# 0	model_1_a	lpa-wel	-44315.47	30166.14	879735.14	18642.67	0.0	5707.58	29194.79	29194.79	6308.73	35988.21	1.8563860009931666e-06	0.0	0.0	1.2480880881677273e-06	8.237712879407176e-07
# 1	model_1_a	lpa-wel	-52536.94	41927.04	631001.95	41298.13	0.0	5631.91	73716.12	73716.12	6083.87	47235.0	9.444978705866191e-07	0.0	0.0	2.1763997649249744e-06	1.4215169971455175e-06
# 2	model_1_a	lpa-wel	-53211.27	38597.29	929770.12	9070.36	0.0	7942.58	15392.6	15392.6	3052.95	34035.09	1.996254141158615e-06	0.0	0.0	2.0856386549418365e-06	1.987186147006694e-06
# 3	model_1_a	lpa-wel	-55575.91	47708.03	658036.86	72229.96	0.0	8083.32	65932.5	65932.5	6877.43	57793.51	2.867441812206457e-06	0.0	0.0	1.6915391392182825e-06	6.581701235620083e-07
# ...
